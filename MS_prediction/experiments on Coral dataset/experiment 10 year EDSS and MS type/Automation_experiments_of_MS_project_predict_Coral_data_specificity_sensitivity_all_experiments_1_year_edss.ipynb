# %% [markdown]
# import all the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stats
import io
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# upload the db file

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #Defines experiment configuration -

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis','MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS'] 
NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']
NO_STANDARD = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', '1_year_EDSS']
NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_PD1_RQ = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_RQ_CTLA4 = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_MALIGNANT = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']

NO_LAG3_NO_TIM3 = ['TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_TIGIT = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']

NO_PD1_RQ_NO_LAG3 = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_TIGIT = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis =   ['TIM3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR = "NO TIGIT"
NO_LAG3_STR ="NO LAG3"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR = "NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_PD1_RQ_STR = "NO PD1 RQ"
NO_RQ_CTLA4_STR = "NO RQ CTLA4"
NO_MALIGNANT_STR = "NO MALIGNANT"
NO_STANDARD_STR = "NO STANDARD"
NO_1_YEAR_EDSS_STR = "NO_1_YEAR_EDSS"
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT,OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_PD1_RQ_STR = "NO_ IGIT, PD1 RQ"
NO_TIGIT_NO_RQ_CTLA4_STR = "NO TIGIT, RQ CTLA4"
NO_TIGIT_NO_MALIGNANT_STR = "NO TIGIT, MALIGNANT"

NO_LAG3_NO_TIM3_STR = "NO LAG3, TIM3"
NO_LAG3_NO_AGE_STR = "NO LAG3, AGE"
NO_LAG3_NO_TIGIT_STR = "NO LAG3, TIGIT"
NO_LAG3_NO_OCB_STR = "NO LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO LAG3, MRI LESION"
NO_LAG3_NO_PD1_RQ_STR = "NO LAG3,PD1 RQ"
NO_LAG3_NO_RQ_CTLA4_STR = "NO LAG3, RQ CTLA4"

NO_PD1_RQ_NO_LAG3_STR = "NO_PD1 RQ, LAG3"
NO_PD1_RQ_NO_TIM3_STR = "NO PD1 RQ, TIM3"
NO_PD1_RQ_NO_TIGIT_STR = "NO_PD1 RQ, TIGIT"
NO_PD1_RQ_NO_MRI_LESION_STR = "NO PD1 RQ, MRI LESION"
NO_PD1_RQ_NO_RQ_CTLA4_STR = "NO PD1 RQ, RQ CTLA4"
NO_PD1_RQ_NO_AGE_STR = "NO PD1 RQ, AGE"
NO_PD1_RQ_NO_MALIGNANT_STR = "NO PD1 RQ, MALIGNANT"
NO_PD1_RQ_NO_1_YEAR_EDSS_STR = "NO_PD1_RQ_NO_1_YEAR_EDSS"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_STR =   "NO TIGIT, LAG3, primary EDSS at diagnosis"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE_STR = "NO TIGIT, LAG3, primary EDSS at diagnosis, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# # **helper functions**

# %%
const_seed = 42

# %%
def calcCrossValidation_RMSE(model, df, predictors, outcome):


  # Perform k-fold cross-validation with 10 folds
  kf = KFold(n_splits=df.shape[0])
  accuracy = []
  total_RMSE=0
  for train, test in kf.split(df):
      # print(train)
      # Filter training data
      train_predictors = (df[predictors].iloc[train, :])
      # The target we're using to train the algorithm.
      train_target = df[outcome].iloc[train]
      test_predictors = (df[predictors].iloc[test, :])
      # print(train_predictors)

      # The target we're using to train the algorithm.
      test_target = df[outcome].iloc[test]

      # Training the algorithm using the predictors and target.
      # print(train_target)
      model.fit(train_predictors, train_target)
      predictions = model.predict(test_predictors)
      # print(predictions)
      rmse = sqrt(mean_squared_error(test_target, predictions))  
      # print(rmse)
      total_RMSE += rmse

  return total_RMSE/df.shape[0]
  # return 0

# %%
def calcCrossValidation_Matrix(model, df, predictors, outcome):

  total_tp = 0
  total_tn = 0
  total_fp = 0
  total_fn = 0

  # Perform k-fold cross-validation with 10 folds
  kf = KFold(n_splits=df.shape[0])
  accuracy = []
  for train, test in kf.split(df):
      # print("1")

      # Filter training data
      train_predictors = (df[predictors].iloc[train, :])
      # The target we're using to train the algorithm.
      train_target = df[outcome].iloc[train]
      # print("1")

      test_predictors = (df[predictors].iloc[test, :])
      # The target we're using to train the algorithm.
      test_target = df[outcome].iloc[test]
      # print("1")


      # Training the algorithm using the predictors and target.
      model.fit(train_predictors, train_target)
      predictions = model.predict(test_predictors)
      # cm = confusion_matrix(test_target, predictions)
      # print(cm)
      # print("1")
      # print("test_target")
      test_target = test_target.to_numpy()
      # print(test_target)
      # np.array(df[outcome].values.tolist())
      # print(type(test_target))
      # print("predictions")
      # print(predictions)
      # print(type(predictions))

      tn, fp, fn, tp = perf_measure(test_target, predictions)
      # print("1")

      total_tp += tp
      total_tn += tn
      total_fp += fp
      total_fn += fn

  # print(total_tn, total_fp, total_fn, total_tp)
  return total_tn, total_fp, total_fn, total_tp

# %%
def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
           TP += 1
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
        if y_actual[i]==y_hat[i]==0:
           TN += 1
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1
    # print(TN, FP, FN, TP)
    return(TN, FP, FN, TP)

# %%
def calc_specificity(tn, fp, fn, tp):
  return tn / (tn +fp)

# %%
def calc_sensitivity(tn, fp, fn, tp):
  return tp / (tp +fn)

# %% [markdown]
# # code for automation experiments

# %%
def run_experiment(df, outcome_var, model_type, predictor_var, removed_features, df_experiments):
  model = choose_experiment_model(df, outcome_var, model_type, predictor_var, removed_features, df_experiments)
  if (model_type=='Random Forest Classifier' or model_type=='Logistic Regression'):
    calculations = add_sensitivity_specifity(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments)
  else:
    calculations = add_rmse(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments)
  experiment_results = update_experiment_in_results_df(calculations, removed_features, model_type, df_experiments)
  return experiment_results

# %%
def choose_experiment_model(df, outcome_var, model_type, predictor_var, removed_features, df_experiments):
  if (model_type=='Random Forest Classifier'):
    return RandomForestClassifier(n_estimators=25, min_samples_split=9, max_depth=15, max_features='auto',random_state=SEED)
    # return add_sensitivity_specifity(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments)
  elif (model_type=='Logistic Regression'):
    return LogisticRegression(max_iter = 4000,random_state=SEED)
    # return add_sensitivity_specifity(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments)
  else:
    return RandomForestRegressor(n_estimators = 10, random_state=SEED)
    # return add_rmse(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments)

# %%
def add_sensitivity_specifity(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments):
  tn, fp, fn, tp = calcCrossValidation_Matrix(model, df, predictor_var, outcome_var)
  specificity = calc_specificity(tn, fp, fn, tp)
  sensitivity = calc_sensitivity(tn, fp, fn, tp)
  specifity_sensitivity_list = [specificity, sensitivity]
  return specifity_sensitivity_list

# %%
def add_rmse(model, df, predictor_var, outcome_var, model_type, removed_features, df_experiments):
  rmse = calcCrossValidation_RMSE(model, df, predictor_var, outcome_var)
  rmse_list = [rmse]
  return rmse_list

# %%
def update_experiment_in_results_df(results_list, removed_features, model_type, df_experiments):
  if (len(results_list)==2):
    new_record = {'Model': model_type,'Removed Features': removed_features,'Specificity': results_list[0], 'Sensitivity':results_list[1], 'RMSE': ''}
  else:
    new_record = {'Model': model_type,'Removed Features': removed_features,'Specificity': '', 'Sensitivity':'', 'RMSE':results_list[0]}
  df_experiments = df_experiments.append(new_record, ignore_index=True)
  return df_experiments

# %%
def experiments_RF_LR(df_origin_data,features_list, features_names,df_experiments):
  df_experiments = run_experiment(df_origin_data, OUTCOME_MS_TYPE, RFCLASSIFIER, features_list, features_names, df_experiments)
  df_experiments = run_experiment(df_origin_data, OUTCOME_MS_TYPE, LR, features_list, features_names, df_experiments)
  df_experiments = run_experiment(df_origin_data, OUTCOME_EDSS_POST_10_YEARS, RFREGRESSOR, features_list, features_names, df_experiments)
  return df_experiments

# %% [markdown]
# #**Coral all patients (untreated)**

# %%
const_seed = 42

# %% [markdown]
# pickle creation

# %%
df_coral = pd.read_pickle("/content/gdrive/My Drive/Colab Notebooks/MS_Notebooks/DFDB2Final_coral.pkl")
df_coral

# %%
def min_max_normalize_features(dataframe, numeric_list):
    for num_feature in numeric_list:
        dataframe[num_feature] = (dataframe[num_feature] - dataframe[num_feature].min()) / (
                dataframe[num_feature].max() - dataframe[num_feature].min())
    return dataframe

# %%
# normalized_features = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'age_at_diagnosis','primary_EDSS_at_diagnosis', '1_years_EDSS_from_sample_date', 'MRI_lesion_mass', 'Lymph_Cells', 'PMN_Cells', 'Cells']
normalized_features = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'age_at_diagnosis', 'MRI_lesion_mass']

df_coral = min_max_normalize_features(df_coral, normalized_features)
df_coral = df_coral.rename(columns={'1_years_EDSS_from_sample_date': '1_year_EDSS'})
df_coral

# %%
# categorical_features = ['gender','oligoclonal_band','diagnosis']
# df_livnat_all_patients = pd.get_dummies(df_livnat_all_patients, columns=categorical_features, drop_first=True)
df_coral.drop(['sample_code'], axis='columns', inplace=True)

# %%
df_coral.columns.values
# Out:
# array(['gender', 'age_at_diagnosis', 'diagnosis', 'diagnosis_status',
#        'primary_EDSS_at_diagnosis', 'num_of_medicine_changed',
#        'MRI_lesion_mass', 'oligoclonal_band', 'TIGIT_RQ', 'TIM3_RQ',
#        'LAG3_RQ', 'PD-1_RQ', 'RQ_CTLA4', '1_year_EDSS',
#        '3_years_from_sample', '5_years_from_sample', 'EDSS_post_10_years',
#        'NEG', 'oligoclonal_band_POS', 'F', 'gender_M', 'BENIGN',
#        'MALIGNANT', 'STANDARD', 'diagnosis_RRMS', 'SPMS'], dtype=object)

# %% [markdown]
# # Running all experiments

# %%
df_experiments = pd.DataFrame(columns=['Model','Removed Features','Specificity', 'Sensitivity', 'RMSE']) 

df_experiments = experiments_RF_LR(df_coral,ALL_FEATURES, ALL_FEATURES_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT, NO_TIGIT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral ,NO_LAG3, NO_LAG3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_AGE, NO_AGE_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_OCB, NO_OCB_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_MRI_LESION, NO_MRI_LESION_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_GENDER, NO_GENDER_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_EDSS_AT_DIAGNOSIS, NO_EDSS_AT_DIAGNOSIS_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIM3, NO_TIM3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ, NO_PD1_RQ_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_RQ_CTLA4, NO_RQ_CTLA4_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_MALIGNANT, NO_MALIGNANT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_STANDARD, NO_STANDARD_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_1_YEAR_EDSS, NO_1_YEAR_EDSS_STR,df_experiments)


df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_LAG3, NO_TIGIT_NO_LAG3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_AGE, NO_TIGIT_NO_AGE_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_OCB, NO_TIGIT_NO_OCB_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_MRI_LESION, NO_TIGIT_NO_MRI_LESION_STR,df_experiments)

df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_PD1_RQ, NO_TIGIT_NO_PD1_RQ_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_RQ_CTLA4, NO_TIGIT_NO_RQ_CTLA4_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_MALIGNANT, NO_TIGIT_NO_MALIGNANT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_TIM3, NO_LAG3_NO_TIM3_STR,df_experiments)

df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_TIM3, NO_LAG3_NO_TIM3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_AGE, NO_LAG3_NO_AGE_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_TIGIT, NO_LAG3_NO_TIGIT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_OCB, NO_LAG3_NO_OCB_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_MRI_LESION, NO_LAG3_NO_MRI_LESION_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_PD1_RQ, NO_LAG3_NO_PD1_RQ_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_LAG3_NO_RQ_CTLA4, NO_LAG3_NO_RQ_CTLA4_STR,df_experiments)

df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_LAG3, NO_PD1_RQ_NO_LAG3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_TIM3, NO_PD1_RQ_NO_TIM3_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_TIGIT, NO_PD1_RQ_NO_TIGIT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_MRI_LESION, NO_PD1_RQ_NO_MRI_LESION_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_RQ_CTLA4, NO_PD1_RQ_NO_RQ_CTLA4_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_AGE, NO_PD1_RQ_NO_AGE_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_MALIGNANT, NO_PD1_RQ_NO_MALIGNANT_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_PD1_RQ_NO_1_YEAR_EDSS, NO_PD1_RQ_NO_1_YEAR_EDSS_STR, df_experiments)


df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis, NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_STR,df_experiments)
df_experiments = experiments_RF_LR(df_coral,NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE, NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE_STR,df_experiments)



df_experiments.to_excel('/content/gdrive/MyDrive/Colab Notebooks/experiments_excels/df_specificity_sensitivity_rmse_coral_1_year_edss.xlsx',index=False)
df_experiments
# Out:
#                         Model                                Removed Features  \
# 0    Random Forest Classifier                                    ALL FEATURES
# 1         Logistic Regression                                    ALL FEATURES
# 2     Random Forest Regressor                                    ALL FEATURES
# 3    Random Forest Classifier                                        NO TIGIT
# 4         Logistic Regression                                        NO TIGIT
# 5     Random Forest Regressor                                        NO TIGIT
# 6    Random Forest Classifier                                         NO LAG3
# 7         Logistic Regression                                         NO LAG3
# 8     Random Forest Regressor                                         NO LAG3
# 9    Random Forest Classifier                                          NO AGE
# 10        Logistic Regression                                          NO AGE
# 11    Random Forest Regressor                                          NO AGE
# 12   Random Forest Classifier                                          NO OCB
# 13        Logistic Regression                                          NO OCB
# 14    Random Forest Regressor                                          NO OCB
# 15   Random Forest Classifier                                   NO MRI LESION
# 16        Logistic Regression                                   NO MRI LESION
# 17    Random Forest Regressor                                   NO MRI LESION
# 18   Random Forest Classifier                                       NO GENDER
# 19        Logistic Regression                                       NO GENDER
# 20    Random Forest Regressor                                       NO GENDER
# 21   Random Forest Classifier                            NO EDSS AT DIAGNOSIS
# 22        Logistic Regression                            NO EDSS AT DIAGNOSIS
# 23    Random Forest Regressor                            NO EDSS AT DIAGNOSIS
# 24   Random Forest Classifier                                         NO TIM3
# 25        Logistic Regression                                         NO TIM3
# 26    Random Forest Regressor                                         NO TIM3
# 27   Random Forest Classifier                                       NO PD1 RQ
# 28        Logistic Regression                                       NO PD1 RQ
# 29    Random Forest Regressor                                       NO PD1 RQ
# 30   Random Forest Classifier                                     NO RQ CTLA4
# 31        Logistic Regression                                     NO RQ CTLA4
# 32    Random Forest Regressor                                     NO RQ CTLA4
# 33   Random Forest Classifier                                    NO MALIGNANT
# 34        Logistic Regression                                    NO MALIGNANT
# 35    Random Forest Regressor                                    NO MALIGNANT
# 36   Random Forest Classifier                                     NO STANDARD
# 37        Logistic Regression                                     NO STANDARD
# 38    Random Forest Regressor                                     NO STANDARD
# 39   Random Forest Classifier                                  NO_1_YEAR_EDSS
# 40        Logistic Regression                                  NO_1_YEAR_EDSS
# 41    Random Forest Regressor                                  NO_1_YEAR_EDSS
# 42   Random Forest Classifier                                  NO TIGIT, LAG3
# 43        Logistic Regression                                  NO TIGIT, LAG3
# 44    Random Forest Regressor                                  NO TIGIT, LAG3
# 45   Random Forest Classifier                                   NO TIGIT, AGE
# 46        Logistic Regression                                   NO TIGIT, AGE
# 47    Random Forest Regressor                                   NO TIGIT, AGE
# 48   Random Forest Classifier                                    NO TIGIT,OCB
# 49        Logistic Regression                                    NO TIGIT,OCB
# 50    Random Forest Regressor                                    NO TIGIT,OCB
# 51   Random Forest Classifier                            NO TIGIT, MRI LESION
# 52        Logistic Regression                            NO TIGIT, MRI LESION
# 53    Random Forest Regressor                            NO TIGIT, MRI LESION
# 54   Random Forest Classifier                                NO_ IGIT, PD1 RQ
# 55        Logistic Regression                                NO_ IGIT, PD1 RQ
# 56    Random Forest Regressor                                NO_ IGIT, PD1 RQ
# 57   Random Forest Classifier                              NO TIGIT, RQ CTLA4
# 58        Logistic Regression                              NO TIGIT, RQ CTLA4
# 59    Random Forest Regressor                              NO TIGIT, RQ CTLA4
# 60   Random Forest Classifier                             NO TIGIT, MALIGNANT
# 61        Logistic Regression                             NO TIGIT, MALIGNANT
# 62    Random Forest Regressor                             NO TIGIT, MALIGNANT
# 63   Random Forest Classifier                                   NO LAG3, TIM3
# 64        Logistic Regression                                   NO LAG3, TIM3
# 65    Random Forest Regressor                                   NO LAG3, TIM3
# 66   Random Forest Classifier                                   NO LAG3, TIM3
# 67        Logistic Regression                                   NO LAG3, TIM3
# 68    Random Forest Regressor                                   NO LAG3, TIM3
# 69   Random Forest Classifier                                    NO LAG3, AGE
# 70        Logistic Regression                                    NO LAG3, AGE
# 71    Random Forest Regressor                                    NO LAG3, AGE
# 72   Random Forest Classifier                                  NO LAG3, TIGIT
# 73        Logistic Regression                                  NO LAG3, TIGIT
# 74    Random Forest Regressor                                  NO LAG3, TIGIT
# 75   Random Forest Classifier                                    NO LAG3, OCB
# 76        Logistic Regression                                    NO LAG3, OCB
# 77    Random Forest Regressor                                    NO LAG3, OCB
# 78   Random Forest Classifier                             NO LAG3, MRI LESION
# 79        Logistic Regression                             NO LAG3, MRI LESION
# 80    Random Forest Regressor                             NO LAG3, MRI LESION
# 81   Random Forest Classifier                                  NO LAG3,PD1 RQ
# 82        Logistic Regression                                  NO LAG3,PD1 RQ
# 83    Random Forest Regressor                                  NO LAG3,PD1 RQ
# 84   Random Forest Classifier                               NO LAG3, RQ CTLA4
# 85        Logistic Regression                               NO LAG3, RQ CTLA4
# 86    Random Forest Regressor                               NO LAG3, RQ CTLA4
# 87   Random Forest Classifier                                 NO_PD1 RQ, LAG3
# 88        Logistic Regression                                 NO_PD1 RQ, LAG3
# 89    Random Forest Regressor                                 NO_PD1 RQ, LAG3
# 90   Random Forest Classifier                                 NO PD1 RQ, TIM3
# 91        Logistic Regression                                 NO PD1 RQ, TIM3
# 92    Random Forest Regressor                                 NO PD1 RQ, TIM3
# 93   Random Forest Classifier                                NO_PD1 RQ, TIGIT
# 94        Logistic Regression                                NO_PD1 RQ, TIGIT
# 95    Random Forest Regressor                                NO_PD1 RQ, TIGIT
# 96   Random Forest Classifier                           NO PD1 RQ, MRI LESION
# 97        Logistic Regression                           NO PD1 RQ, MRI LESION
# 98    Random Forest Regressor                           NO PD1 RQ, MRI LESION
# 99   Random Forest Classifier                             NO PD1 RQ, RQ CTLA4
# 100       Logistic Regression                             NO PD1 RQ, RQ CTLA4
# 101   Random Forest Regressor                             NO PD1 RQ, RQ CTLA4
# 102  Random Forest Classifier                                  NO PD1 RQ, AGE
# 103       Logistic Regression                                  NO PD1 RQ, AGE
# 104   Random Forest Regressor                                  NO PD1 RQ, AGE
# 105  Random Forest Classifier                            NO PD1 RQ, MALIGNANT
# 106       Logistic Regression                            NO PD1 RQ, MALIGNANT
# 107   Random Forest Regressor                            NO PD1 RQ, MALIGNANT
# 108  Random Forest Classifier                        NO_PD1_RQ_NO_1_YEAR_EDSS
# 109       Logistic Regression                        NO_PD1_RQ_NO_1_YEAR_EDSS
# 110   Random Forest Regressor                        NO_PD1_RQ_NO_1_YEAR_EDSS
# 111  Random Forest Classifier       NO TIGIT, LAG3, primary EDSS at diagnosis
# 112       Logistic Regression       NO TIGIT, LAG3, primary EDSS at diagnosis
# 113   Random Forest Regressor       NO TIGIT, LAG3, primary EDSS at diagnosis
# 114  Random Forest Classifier  NO TIGIT, LAG3, primary EDSS at diagnosis, AGE
# 115       Logistic Regression  NO TIGIT, LAG3, primary EDSS at diagnosis, AGE
# 116   Random Forest Regressor  NO TIGIT, LAG3, primary EDSS at diagnosis, AGE
#
#     Specificity Sensitivity      RMSE
# 0      0.972973        0.85
# 1      0.972973        0.85
# 2                            0.790351
# 3      0.972973        0.85
# 4      0.972973        0.85
# 5                            0.800877
# 6      0.972973         0.8
# 7      0.972973        0.85
# 8                            0.750877
# 9      0.972973         0.8
# 10     0.972973         0.8
# 11                           0.759649
# 12            1         0.8
# 13     0.972973        0.85
# 14                           0.820175
# 15            1         0.8
# 16     0.972973         0.8
# 17                            0.77807
# 18            1         0.8
# 19     0.918919        0.85
# 20                           0.792982
# 21            1         0.8
# 22     0.972973        0.85
# 23                           0.807895
# 24     0.972973         0.8
# 25     0.972973         0.8
# 26                           0.791228
# 27     0.972973         0.8
# 28     0.972973         0.8
# 29                           0.785088
# 30     0.972973         0.8
# 31     0.972973         0.8
# 32                           0.762281
# 33     0.891892         0.7
# 34     0.891892        0.75
# 35                            1.05088
# 36            1         0.8
# 37     0.918919         0.8
# 38                           0.924561
# 39     0.972973         0.8
# 40     0.972973         0.8
# 41                           0.835088
# 42     0.972973        0.85
# 43     0.972973        0.85
# 44                           0.788596
# 45     0.972973        0.85
# 46     0.972973        0.85
# 47                           0.754386
# 48            1        0.85
# 49     0.972973        0.85
# 50                           0.780702
# 51            1        0.85
# 52     0.972973         0.8
# 53                           0.832456
# 54            1        0.85
# 55     0.972973         0.8
# 56                           0.812281
# 57            1        0.85
# 58     0.972973         0.8
# 59                           0.786842
# 60     0.864865        0.65
# 61     0.918919        0.75
# 62                            0.99386
# 63     0.972973        0.85
# 64     0.972973         0.8
# 65                           0.741228
# 66     0.972973        0.85
# 67     0.972973         0.8
# 68                           0.741228
# 69     0.972973        0.85
# 70     0.972973         0.8
# 71                           0.752632
# 72     0.972973        0.85
# 73     0.972973        0.85
# 74                           0.788596
# 75            1        0.85
# 76     0.972973        0.85
# 77                           0.783333
# 78     0.972973        0.85
# 79     0.972973         0.8
# 80                           0.778947
# 81            1        0.85
# 82     0.972973         0.8
# 83                           0.778947
# 84            1        0.85
# 85     0.972973         0.8
# 86                           0.745614
# 87            1        0.85
# 88     0.972973         0.8
# 89                           0.778947
# 90            1        0.85
# 91     0.972973         0.8
# 92                           0.789474
# 93            1        0.85
# 94     0.972973         0.8
# 95                           0.812281
# 96            1        0.85
# 97     0.972973         0.8
# 98                           0.780702
# 99            1        0.85
# 100    0.945946         0.8
# 101                          0.792982
# 102    0.972973        0.85
# 103    0.972973         0.8
# 104                          0.766667
# 105    0.864865        0.65
# 106    0.891892        0.75
# 107                           1.02719
# 108           1        0.85
# 109    0.972973         0.8
# 110                          0.812281
# 111           1        0.85
# 112    0.972973        0.85
# 113                          0.790351
# 114    0.972973        0.85
# 115    0.972973        0.85
# 116                          0.734211
