# %% [markdown]
# #Livnat untreated patients only

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','oligoclonal_band_POS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_LYMPH_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_PMN_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M']
NO_LYMPH_CELLS_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_LYMPH_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_PMN_CELLS_STR = "NO PMN CELLS"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_LYMPH_CELLS_STR = "NO TIGIT, LYMPH CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_PMN_CELLS_STR = "NO TIGIT, PMN CELLS"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"

NO_LAG3_NO_LYMPH_CELLS_STR = "NO_LAG3, LYMPH_CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_LYMPH_CELLS_NO_AGE_STR = "NO_LYMPH_CELLS, AGE"
NO_LYMPH_CELLS_NO_PMN_CELLS_STR = "NO_LYMPH_CELLS, PMN_CELLS"
NO_LYMPH_CELLS_NO_OCB_STR = "NO_LYMPH_CELLS, OCB"
NO_LYMPH_CELLS_NO_MRI_LESION_STR = "NO_LYMPH_CELLS, MRI_LESION"


#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_STR = "NO_TIGIT, LAG3, LYMPH_CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE_STR = "NO_TIGIT, LAG3, LYMPH_CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "diagnosis_SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# #Livnat all patients

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','oligoclonal_band_POS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_LYMPH_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_PMN_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']

NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS']
NO_LYMPH_CELLS_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M']
NO_LYMPH_CELLS_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_LYMPH_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_PMN_CELLS_STR = "NO PMN CELLS"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_LYMPH_CELLS_STR = "NO TIGIT, LYMPH CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_PMN_CELLS_STR = "NO TIGIT, PMN CELLS"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"

NO_LAG3_NO_LYMPH_CELLS_STR = "NO_LAG3, LYMPH_CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_LYMPH_CELLS_NO_AGE_STR = "NO_LYMPH_CELLS, AGE"
NO_LYMPH_CELLS_NO_PMN_CELLS_STR = "NO_LYMPH_CELLS, PMN_CELLS"
NO_LYMPH_CELLS_NO_OCB_STR = "NO_LYMPH_CELLS, OCB"
NO_LYMPH_CELLS_NO_MRI_LESION_STR = "NO_LYMPH_CELLS, MRI_LESION"


#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_STR = "NO_TIGIT, LAG3, LYMPH_CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE_STR = "NO_TIGIT, LAG3, LYMPH_CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "diagnosis_SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# #Livnat untreated patients only 1 years edss

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','oligoclonal_band_POS','1_year_EDSS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']


#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_LYMPH_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_PMN_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','1_year_EDSS']
NO_LYMPH_CELLS_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_LYMPH_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_PMN_CELLS_STR = "NO PMN CELLS"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_1_YEAR_EDSS_STR= "NO_1_YEAR_EDSS"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_LYMPH_CELLS_STR = "NO TIGIT, LYMPH CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_PMN_CELLS_STR = "NO TIGIT, PMN CELLS"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"

NO_LAG3_NO_LYMPH_CELLS_STR = "NO_LAG3, LYMPH_CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_LYMPH_CELLS_NO_AGE_STR = "NO_LYMPH_CELLS, AGE"
NO_LYMPH_CELLS_NO_PMN_CELLS_STR = "NO_LYMPH_CELLS, PMN_CELLS"
NO_LYMPH_CELLS_NO_OCB_STR = "NO_LYMPH_CELLS, OCB"
NO_LYMPH_CELLS_NO_MRI_LESION_STR = "NO_LYMPH_CELLS, MRI_LESION"


#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_STR = "NO_TIGIT, LAG3, LYMPH_CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE_STR = "NO_TIGIT, LAG3, LYMPH_CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "diagnosis_SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# #Livnat all patients 1 year edss

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','oligoclonal_band_POS','1_year_EDSS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS']


#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_LYMPH_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_PMN_CELLS = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','Lymph_Cells','PMN_Cells','gender_M','1_year_EDSS']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','Lymph_Cells','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS_NO_PMN_CELLS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','1_year_EDSS']
NO_LYMPH_CELLS_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','1_year_EDSS']
NO_LYMPH_CELLS_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS = ['TIM3_RQ','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE = ['TIM3_RQ', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','PMN_Cells','gender_M','oligoclonal_band_POS','1_year_EDSS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_LYMPH_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_PMN_CELLS_STR = "NO PMN CELLS"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_1_YEAR_EDSS_STR= "NO_1_YEAR_EDSS"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_LYMPH_CELLS_STR = "NO TIGIT, LYMPH CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_PMN_CELLS_STR = "NO TIGIT, PMN CELLS"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"

NO_LAG3_NO_LYMPH_CELLS_STR = "NO_LAG3, LYMPH_CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_LYMPH_CELLS_NO_AGE_STR = "NO_LYMPH_CELLS, AGE"
NO_LYMPH_CELLS_NO_PMN_CELLS_STR = "NO_LYMPH_CELLS, PMN_CELLS"
NO_LYMPH_CELLS_NO_OCB_STR = "NO_LYMPH_CELLS, OCB"
NO_LYMPH_CELLS_NO_MRI_LESION_STR = "NO_LYMPH_CELLS, MRI_LESION"


#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_STR = "NO_TIGIT, LAG3, LYMPH_CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_LYMPH_CELLS_NO_AGE_STR = "NO_TIGIT, LAG3, LYMPH_CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "diagnosis_SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# # Coral

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','MALIGNANT', 'STANDARD']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis','MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD'] 
NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD']
NO_STANDARD = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT']
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIGIT_NO_PD1_RQ = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIGIT_NO_RQ_CTLA4 = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_TIGIT_NO_MALIGNANT = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD']

NO_LAG3_NO_TIM3 = ['TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3_NO_TIGIT = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3_NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_LAG3_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']

NO_PD1_RQ_NO_LAG3 = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_TIGIT = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
NO_PD1_RQ_NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis =   ['TIM3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR = "NO TIGIT"
NO_LAG3_STR ="NO LAG3"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR = "NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_PD1_RQ_STR = "NO PD1 RQ"
NO_RQ_CTLA4_STR = "NO RQ CTLA4"
NO_MALIGNANT_STR = "NO MALIGNANT"
NO_STANDARD_STR = "NO STANDARD"
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT,OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_PD1_RQ_STR = "NO_ IGIT, PD1 RQ"
NO_TIGIT_NO_RQ_CTLA4_STR = "NO TIGIT, RQ CTLA4"
NO_TIGIT_NO_MALIGNANT_STR = "NO TIGIT, MALIGNANT"

NO_LAG3_NO_TIM3_STR = "NO LAG3, TIM3"
NO_LAG3_NO_AGE_STR = "NO LAG3, AGE"
NO_LAG3_NO_TIGIT_STR = "NO LAG3, TIGIT"
NO_LAG3_NO_OCB_STR = "NO LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO LAG3, MRI LESION"
NO_LAG3_NO_PD1_RQ_STR = "NO LAG3,PD1 RQ"
NO_LAG3_NO_RQ_CTLA4_STR = "NO LAG3, RQ CTLA4"

NO_PD1_RQ_NO_LAG3_STR = "NO_PD1 RQ, LAG3"
NO_PD1_RQ_NO_TIM3_STR = "NO PD1 RQ, TIM3"
NO_PD1_RQ_NO_TIGIT_STR = "NO_PD1 RQ, TIGIT"
NO_PD1_RQ_NO_MRI_LESION_STR = "NO PD1 RQ, MRI LESION"
NO_PD1_RQ_NO_RQ_CTLA4_STR = "NO PD1 RQ, RQ CTLA4"
NO_PD1_RQ_NO_AGE_STR = "NO PD1 RQ, AGE"
NO_PD1_RQ_NO_MALIGNANT_STR = "NO PD1 RQ, MALIGNANT"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_STR =   "NO TIGIT, LAG3, primary EDSS at diagnosis"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE_STR = "NO TIGIT, LAG3, primary EDSS at diagnosis, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# # Coral 1 year edss

# %%
#lists of selected features

ALL_FEATURES = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
#REMOVE ONE FEATURE
NO_TIGIT =  ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3 =['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_AGE =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_OCB =['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_GENDER = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_EDSS_AT_DIAGNOSIS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis','MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS'] 
NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']
NO_STANDARD = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', '1_year_EDSS']
NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_AGE = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_OCB = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_MRI_LESION = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_PD1_RQ = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_RQ_CTLA4 = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_TIGIT_NO_MALIGNANT = ['TIM3_RQ', 'LAG3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']

NO_LAG3_NO_TIM3 = ['TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_TIGIT = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_OCB = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M', 'MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_PD1_RQ = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_LAG3_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']

NO_PD1_RQ_NO_LAG3 = ['TIM3_RQ', 'TIGIT_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_TIM3 = ['TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_TIGIT = ['TIM3_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_MRI_LESION = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_RQ_CTLA4 = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_AGE = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_MALIGNANT = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS', 'STANDARD', '1_year_EDSS']
NO_PD1_RQ_NO_1_YEAR_EDSS = ['TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'RQ_CTLA4','age_at_diagnosis', 'primary_EDSS_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis =   ['TIM3_RQ','PD-1_RQ', 'RQ_CTLA4','age_at_diagnosis', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE = ['TIM3_RQ', 'PD-1_RQ', 'RQ_CTLA4', 'MRI_lesion_mass','gender_M','oligoclonal_band_POS','MALIGNANT', 'STANDARD', '1_year_EDSS']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR = "NO TIGIT"
NO_LAG3_STR ="NO LAG3"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR = "NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_PD1_RQ_STR = "NO PD1 RQ"
NO_RQ_CTLA4_STR = "NO RQ CTLA4"
NO_MALIGNANT_STR = "NO MALIGNANT"
NO_STANDARD_STR = "NO STANDARD"
NO_1_YEAR_EDSS_STR = "NO_1_YEAR_EDSS"
#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT,OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_PD1_RQ_STR = "NO_ IGIT, PD1 RQ"
NO_TIGIT_NO_RQ_CTLA4_STR = "NO TIGIT, RQ CTLA4"
NO_TIGIT_NO_MALIGNANT_STR = "NO TIGIT, MALIGNANT"

NO_LAG3_NO_TIM3_STR = "NO LAG3, TIM3"
NO_LAG3_NO_AGE_STR = "NO LAG3, AGE"
NO_LAG3_NO_TIGIT_STR = "NO LAG3, TIGIT"
NO_LAG3_NO_OCB_STR = "NO LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO LAG3, MRI LESION"
NO_LAG3_NO_PD1_RQ_STR = "NO LAG3,PD1 RQ"
NO_LAG3_NO_RQ_CTLA4_STR = "NO LAG3, RQ CTLA4"

NO_PD1_RQ_NO_LAG3_STR = "NO_PD1 RQ, LAG3"
NO_PD1_RQ_NO_TIM3_STR = "NO PD1 RQ, TIM3"
NO_PD1_RQ_NO_TIGIT_STR = "NO_PD1 RQ, TIGIT"
NO_PD1_RQ_NO_MRI_LESION_STR = "NO PD1 RQ, MRI LESION"
NO_PD1_RQ_NO_RQ_CTLA4_STR = "NO PD1 RQ, RQ CTLA4"
NO_PD1_RQ_NO_AGE_STR = "NO PD1 RQ, AGE"
NO_PD1_RQ_NO_MALIGNANT_STR = "NO PD1 RQ, MALIGNANT"
NO_PD1_RQ_NO_1_YEAR_EDSS_STR = "NO_PD1_RQ_NO_1_YEAR_EDSS"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_STR =   "NO TIGIT, LAG3, primary EDSS at diagnosis"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_LAG3_NO_primary_EDSS_at_diagnosis_NO_AGE_STR = "NO TIGIT, LAG3, primary EDSS at diagnosis, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# #Nitzan with primary EDSS and 1 year EDSS

# %%
#lists of selected features

ALL_FEATURES = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
#REMOVE ONE FEATURE
NO_TIGIT =  ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_AGE =['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_GENDER = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_EDSS_AT_DIAGNOSIS = ['MRI_lesion_mass', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis','TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_PRIMARY_EDSS_SAMPLE_DATE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OTHER_TREATMENT = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_UNTREATED = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MED_IFN = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_TYSABRI', 'cells_total']
NO_MED_TYSABRI = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'cells_total']


#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIGIT_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ','LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_LAG3_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'TIM3_RQ', 'TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS','TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_PRIMARY_EDSS = ['MRI_lesion_mass', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male','OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis','TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_TOTAL_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_1_YEAR_EDSS_STR= "NO_1_YEAR_EDSS"
NO_PRIMARY_EDSS_SAMPLE_DATE_STR = "NO_PRIMARY_EDSS_SAMPLE_DATE"
NO_OTHER_TREATMENT_STR = "NO_OTHER_TREATMENT"
NO_UNTREATED_STR = "NO_UNTREATED"
NO_MED_IFN_STR = "NO_MED_IFN"
NO_MED_TYSABRI_STR = "NO_MED_TYSABRI"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_TOTAL_CELLS_STR = "NO TIGIT, TOTAL CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_TIM3_STR = "NO_TIGIT_NO_TIM3"

NO_LAG3_NO_TOTAL_CELLS_STR = "NO LAG3, TOTAL CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_TOTAL_CELLS_NO_AGE_STR = "NO TOTAL CELLS, AGE"
NO_TOTAL_CELLS_NO_PRIMARY_EDSS_STR = "NO TOTAL CELLS, PRIMARY EDSS"
NO_TOTAL_CELLS_NO_OCB_STR = "NO TOTAL CELLS, OCB"
NO_TOTAL_CELLS_NO_MRI_LESION_STR = "NO TOTAL CELLS, MRI LESION"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIGIT, LAG3, TOTAL CELLS"
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIM3, LAG3, TOTAL CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE_STR = "NO_TIGIT, TIM3, TOTAL CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# # Nitzan with 1 year EDSS without primary EDSS

# %%
#lists of selected features

ALL_FEATURES = ['MRI_lesion_mass', 'primary_EDSS_at_sample_date', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
#REMOVE ONE FEATURE
NO_TIGIT =  ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_AGE =['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MRI_LESION = ['primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_GENDER = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_EDSS_AT_DIAGNOSIS = ['MRI_lesion_mass', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis','TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OTHER_TREATMENT = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_UNTREATED = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MED_IFN = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_TYSABRI', 'cells_total']
NO_MED_TYSABRI = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'cells_total']


#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIGIT_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ','LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_LAG3_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'TIM3_RQ', 'TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS','TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_PRIMARY_EDSS = ['MRI_lesion_mass', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male','OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', '1_years_EDSS', 'age_at_diagnosis', 'TIM3_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'age_at_diagnosis','TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis',  '1_years_EDSS', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_TOTAL_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_1_YEAR_EDSS_STR= "NO_1_YEAR_EDSS"
NO_PRIMARY_EDSS_SAMPLE_DATE_STR = "NO_PRIMARY_EDSS_SAMPLE_DATE"
NO_OTHER_TREATMENT_STR = "NO_OTHER_TREATMENT"
NO_UNTREATED_STR = "NO_UNTREATED"
NO_MED_IFN_STR = "NO_MED_IFN"
NO_MED_TYSABRI_STR = "NO_MED_TYSABRI"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_TOTAL_CELLS_STR = "NO TIGIT, TOTAL CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_TIM3_STR = "NO_TIGIT_NO_TIM3"

NO_LAG3_NO_TOTAL_CELLS_STR = "NO LAG3, TOTAL CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_TOTAL_CELLS_NO_AGE_STR = "NO TOTAL CELLS, AGE"
NO_TOTAL_CELLS_NO_PRIMARY_EDSS_STR = "NO TOTAL CELLS, PRIMARY EDSS"
NO_TOTAL_CELLS_NO_OCB_STR = "NO TOTAL CELLS, OCB"
NO_TOTAL_CELLS_NO_MRI_LESION_STR = "NO TOTAL CELLS, MRI LESION"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIGIT, LAG3, TOTAL CELLS"
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIM3, LAG3, TOTAL CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE_STR = "NO_TIGIT, TIM3, TOTAL CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# # Nitzan with primary EDSS without 1 year EDSS

# %%
#lists of selected features

ALL_FEATURES = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
#REMOVE ONE FEATURE
NO_TIGIT =  ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date','age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_AGE =['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_GENDER = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_EDSS_AT_DIAGNOSIS = ['MRI_lesion_mass', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis','TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_PRIMARY_EDSS_SAMPLE_DATE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_OTHER_TREATMENT = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_UNTREATED = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_MED_IFN = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_TYSABRI', 'cells_total']
NO_MED_TYSABRI = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'med_IFN', 'cells_total']


#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIGIT_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'TIM3_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ','LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_TIGIT_NO_TIM3 = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_LAG3_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'TIM3_RQ', 'TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']
NO_LAG3_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI', 'cells_total']

NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date','TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_PRIMARY_EDSS = ['MRI_lesion_mass', 'primary_EDSS_at_sample_date', 'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_OCB = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date','age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male','OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TOTAL_CELLS_NO_MRI_LESION = ['primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ', 'TIGIT_RQ', 'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'age_at_diagnosis', 'TIM3_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date', 'age_at_diagnosis','TIGIT_RQ','PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE = ['MRI_lesion_mass', 'primary_EDSS_at_diagnosis', 'primary_EDSS_at_sample_date',  'LAG3_RQ', 'PD-1_RQ', 'Male', 'positive_OCB', 'OTHER_TREATMENT', 'UNTREATED', 'med_IFN', 'med_TYSABRI']





#lists of removed features as String 

ALL_FEATURES_STR = "ALL FEATURES"
#REMOVE ONE FEATURE
NO_TIGIT_STR =  "NO TIGIT"
NO_LAG3_STR = "NO LAG3"
NO_TOTAL_CELLS_STR = "NO LYMPH CELLS"
NO_AGE_STR = "NO AGE"
NO_OCB_STR ="NO OCB"
NO_MRI_LESION_STR ="NO MRI LESION"
NO_GENDER_STR = "NO GENDER"
NO_EDSS_AT_DIAGNOSIS_STR = "NO EDSS AT DIAGNOSIS"
NO_TIM3_STR = "NO TIM3"
NO_1_YEAR_EDSS_STR= "NO_1_YEAR_EDSS"
NO_PRIMARY_EDSS_SAMPLE_DATE_STR = "NO_PRIMARY_EDSS_SAMPLE_DATE"
NO_OTHER_TREATMENT_STR = "NO_OTHER_TREATMENT"
NO_UNTREATED_STR = "NO_UNTREATED"
NO_MED_IFN_STR = "NO_MED_IFN"
NO_MED_TYSABRI_STR = "NO_MED_TYSABRI"

#REMOVE TWO FEATURES
NO_TIGIT_NO_LAG3_STR = "NO TIGIT, LAG3"
NO_TIGIT_NO_TOTAL_CELLS_STR = "NO TIGIT, TOTAL CELLS"
NO_TIGIT_NO_AGE_STR = "NO TIGIT, AGE"
NO_TIGIT_NO_OCB_STR = "NO TIGIT, OCB"
NO_TIGIT_NO_MRI_LESION_STR = "NO TIGIT, MRI LESION"
NO_TIGIT_NO_TIM3_STR = "NO_TIGIT_NO_TIM3"

NO_LAG3_NO_TOTAL_CELLS_STR = "NO LAG3, TOTAL CELLS"
NO_LAG3_NO_AGE_STR = "NO_LAG3, AGE"
NO_LAG3_NO_PMN_CELLS_STR = "NO_LAG3, PMN_CELLS"
NO_LAG3_NO_OCB_STR = "NO_LAG3, OCB"
NO_LAG3_NO_MRI_LESION_STR = "NO_LAG3, MRI_LESION"

NO_TOTAL_CELLS_NO_AGE_STR = "NO TOTAL CELLS, AGE"
NO_TOTAL_CELLS_NO_PRIMARY_EDSS_STR = "NO TOTAL CELLS, PRIMARY EDSS"
NO_TOTAL_CELLS_NO_OCB_STR = "NO TOTAL CELLS, OCB"
NO_TOTAL_CELLS_NO_MRI_LESION_STR = "NO TOTAL CELLS, MRI LESION"

#REMOVE THREE FEATURES
NO_TIGIT_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIGIT, LAG3, TOTAL CELLS"
NO_TIM3_NO_LAG3_NO_TOTAL_CELLS_STR = "NO TIM3, LAG3, TOTAL CELLS"

#REMOVE FOUR FEATURES
NO_TIGIT_NO_TIM3_NO_TOTAL_CELLS_NO_AGE_STR = "NO_TIGIT, TIM3, TOTAL CELLS, AGE"





#lists of models
RFCLASSIFIER = "Random Forest Classifier"
LR = "Logistic Regression"
RFREGRESSOR = "Random Forest Regressor"


#lists of outcome
OUTCOME_MS_TYPE = "SPMS"
OUTCOME_EDSS_POST_10_YEARS = "EDSS_post_10_years"

#const seed all runs
SEED = 42

# %% [markdown]
# #Michal
